# %%
import numpy as np
import scvi
import matplotlib.pyplot as plt
# Out:
# /Users/leanderdiaz-bone/Developer/scvi-tools/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /Users/leanderdiaz-bone/Developer/scvi-tools/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (

# %%
def computeVars(zs):
    vars = []
    for i in range(zs.shape[1]):
        vars.append(np.var(np.array(np.transpose(zs.cpu().detach())[i])))
    return vars

# %%
vaeVP = scvi.model.SCVI.load("models/test2")
adata = vaeVP.adata
prior = vaeVP.module.prior
# Out:
# INFO     No backup URL provided for missing file models/test2/model.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Developer/scvi-tools/scvi/model/base/_utils.py:69, in _load_saved_files(dir_path, load_adata, prefix, map_location, backup_url)
#      68     _download(backup_url, dir_path, model_file_name)
# ---> 69     model = torch.load(model_path, map_location=map_location)
#      70 except FileNotFoundError as exc:
#
# File /Applications/Anaconda/anaconda3/envs/scvi-tools-dev-n/lib/python3.11/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#
# File /Applications/Anaconda/anaconda3/envs/scvi-tools-dev-n/lib/python3.11/site-packages/torch/serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     270 if _is_path(name_or_buffer):
# --> 271     return _open_file(name_or_buffer, mode)
#     272 else:
#
# File /Applications/Anaconda/anaconda3/envs/scvi-tools-dev-n/lib/python3.11/site-packages/torch/serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/test2/model.pt'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 vaeVP = scvi.model.SCVI.load("models/test2")
#       2 adata = vaeVP.adata
#       3 prior = vaeVP.module.prior
#
# File ~/Developer/scvi-tools/scvi/model/base/_base_model.py:682, in BaseModelClass.load(cls, dir_path, adata, use_gpu, accelerator, device, prefix, backup_url)
#     668 load_adata = adata is None
#     669 _, _, device = parse_device_args(
#     670     use_gpu=use_gpu,
#     671     accelerator=accelerator,
#    (...)
#     674     validate_single_device=True,
#     675 )
#     677 (
#     678     attr_dict,
#     679     var_names,
#     680     model_state_dict,
#     681     new_adata,
# --> 682 ) = _load_saved_files(
#     683     dir_path,
#     684     load_adata,
#     685     map_location=device,
#     686     prefix=prefix,
#     687     backup_url=backup_url,
#     688 )
#     689 adata = new_adata if new_adata is not None else adata
#     691 _validate_var_names(adata, var_names)
#
# File ~/Developer/scvi-tools/scvi/model/base/_utils.py:71, in _load_saved_files(dir_path, load_adata, prefix, map_location, backup_url)
#      69     model = torch.load(model_path, map_location=map_location)
#      70 except FileNotFoundError as exc:
# ---> 71     raise ValueError(
#      72         f"Failed to load model file at {model_path}. "
#      73         "If attempting to load a saved model from <v0.15.0, please use the util function "
#      74         "`convert_legacy_save` to convert to an updated format."
#      75     ) from exc
#      77 model_state_dict = model["model_state_dict"]
#      78 var_names = model["var_names"]
#
# ValueError: Failed to load model file at models/test2/model.pt. If attempting to load a saved model from <v0.15.0, please use the util function `convert_legacy_save` to convert to an updated format.

# %%
pseudo_inputs, _ = vaeVP.module.prior.get_pseudo_inputs()
plt.plot(pseudo_inputs.cpu().detach()[1])
plt.show()
plt.plot(np.linspace(1,1200,1200),np.array(adata.X.todense()[1])[0])

# %%
inputs = prior.pseudo_transfromer(prior.pseudo_inputs)
dist, zs = prior.encoder(inputs)
computeVars(zs)
# Out:
# [1.0541713, 0.24453135]

# %%
vae_SD = scvi.model.SCVI(adata, prior_distribution = "sdnormal")
vae_N  = scvi.model.SCVI(adata, prior_distribution = "normal")
vae_MG = scvi.model.SCVI(adata, prior_distribution = "mixofgaus", prior_kwargs={"k":100})
vae_VP = scvi.model.SCVI(adata, prior_distribution = "vamp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vae_SD = scvi.model.SCVI(adata, prior_distribution = "sdnormal")
#       2 vae_N  = scvi.model.SCVI(adata, prior_distribution = "normal")
#       3 vae_MG = scvi.model.SCVI(adata, prior_distribution = "mixofgaus", prior_kwargs={"k":100})
#
# NameError: name 'adata' is not defined
